# %% [markdown]
# # 1. Creating formulas
# Write the following mathematical formula in Python:
#
# \begin{align}
#  result = 6a^3 - \frac{8b^2 }{4c} + 11
# \end{align}

# %%
a = 2
b = 3
c = 2

# %%
# Your formula here:
result = int((6*a**3)-((8*b**2)/(4*c))+11)

# %%
assert result == 50

# %% [markdown]
# # 2. Floating point pitfalls
# Show that `0.1 + 0.2 == 0.3`

# %%
# Your solution here
from decimal import Decimal

# This won't work:
# assert 0.1 + 0.2 == 0.3
sum_str = Decimal('0.1') + Decimal('0.2')
print (sum_str)
assert sum_str == Decimal('0.3')
#assert  sum_str == 0.3
# Out:
# 0.3
